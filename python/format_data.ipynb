# %%
import csv
import numpy as np

# %% [markdown]
# **Format data as JSON**
#
# Create 1) nodes with details about each paper and 2) links with source/target representing citations

# %%
def make_node(row):
    return {
        "id": row[1].lower() + " " + row[0],
        "year": int(row[0]),
        "title": row[2],
        "citations": int(row[3]),
        "social_network": [r.lower().strip() for r in row[4].split(",")],
        "sample_size": int(row[5]),
        "sample_country": [r.lower().strip() for r in row[6].split(",")],
        "study_type": [r.lower().strip() for r in row[7].split(",")],
        "variables": [r.lower().strip() for r in row[8].split(",")]
    }

# %%
filepath = "../data/data.tsv"

# %%
in_dataset = ['acquisti & gross 2006', 'banks et al 2010', 'bartsch & dienlin 2016', 'bateman et al 2011', 'benson et al 2015', 'buchi et al 2016', 'collins et al 2012', 'coventry et al 2014', 'cranor et al 1999', 'de wolf et al 2014', 'debatin et al 2009', 'dienlin & trepte 2014', 'dinev & hart 2005', 'doherty & lang 2014', 'dong et al 2015', 'drennan et al 2006', 'dwyer et al 2007', 'feng & xie 2014', 'fox & royne 2018', 'garg et al 2014', 'golbeck & mauriello 2016', 'govani & pashley 2005', 'graeff & harmon 2002', 'hajli & lin 2016', 'hazari & brown 2013', 'heirman et al 2013', 'hoofnagle et al 2010', 'hossain & zhang 2015', 'jensen et al 2005', 'jiang et al 2013', 'johnson et al 2012', 'keith et al 2013', 'kezer et al 2016', 'kisilevich & mansmann 2010', 'krasnova & kift 2012', 'lawler et al 2012', 'lin & liu 2012', 'litt 2013', 'liu et al 2011', 'madejski et al 2012', 'malik et al 2016', 'mcknight et al 2010', 'mesch 2010', 'millham & atkin 2016', 'milne & culnan 2004', 'miltgen & smith 2015', 'moll et al 2014', 'orito et al 2014', 'ozdemir et al 2017', 'paine et al 2007', 'park 2011', 'park et al 2012', 'pitkanen et al 2012', 'posey et al 2010', 'potzch et al 2010', 'reynolds et al 2011', 'staddon et al 2012', 'steijn et al 2016', 'stutzman et al 2011', 'taddicken 2014', 'torres 2012', 'turow 2003', 'tuunainen et al 2009', 'veltri et al 2011', 'wills & zeljkovic 2011', 'xu et al 2008', 'yao et al 2007', 'youn 2009', 'young & quan-haase 2009', 'zlatolas et al 2015']
nodes = []
links = []

with open(filepath, 'rU') as fd:
    rd = csv.reader(fd, delimiter="\t", quotechar='"')
    for row in rd:
        if row[0] != "year":
            # Make nodes
            nodes.append(make_node(row))
            citations = [r.lower() for r in row[9].split(",")]
            for c in citations:
                # Make links
                link = {"source": row[1].lower() + " " + row[0], "target": c}
                if c in in_dataset and link not in links: links.append(link)

# %%
import json

# %%
json.dumps(nodes)
json.dumps(links)
# Out:
# '[{"source": "bartsch & dienlin 2016", "target": "acquisti & gross 2006"}, {"source": "bartsch & dienlin 2016", "target": "hoofnagle et al 2010"}, {"source": "bartsch & dienlin 2016", "target": "litt 2013"}, {"source": "bartsch & dienlin 2016", "target": "taddicken 2014"}, {"source": "buchi et al 2016", "target": "feng & xie 2014"}, {"source": "buchi et al 2016", "target": "park et al 2012"}, {"source": "buchi et al 2016", "target": "taddicken 2014"}, {"source": "coventry et al 2014", "target": "jensen et al 2005"}, {"source": "coventry et al 2014", "target": "drennan et al 2006"}, {"source": "de wolf et al 2014", "target": "acquisti & gross 2006"}, {"source": "de wolf et al 2014", "target": "dwyer et al 2007"}, {"source": "debatin et al 2009", "target": "acquisti & gross 2006"}, {"source": "debatin et al 2009", "target": "litt 2013"}, {"source": "debatin et al 2009", "target": "stutzman et al 2011"}, {"source": "dienlin & trepte 2014", "target": "yao et al 2007"}, {"source": "doherty & lang 2014", "target": "acquisti & gross 2006"}, {"source": "doherty & lang 2014", "target": "veltri et al 2011"}, {"source": "doherty & lang 2014", "target": "turow 2003"}, {"source": "doherty & lang 2014", "target": "posey et al 2010"}, {"source": "dong et al 2015", "target": "liu et al 2011"}, {"source": "drennan et al 2006", "target": "graeff & harmon 2002"}, {"source": "dwyer et al 2007", "target": "acquisti & gross 2006"}, {"source": "feng & xie 2014", "target": "young & quan-haase 2009"}, {"source": "fox & royne 2018", "target": "milne & culnan 2004"}, {"source": "fox & royne 2018", "target": "wills & zeljkovic 2011"}, {"source": "fox & royne 2018", "target": "youn 2009"}, {"source": "garg et al 2014", "target": "drennan et al 2006"}, {"source": "garg et al 2014", "target": "hoofnagle et al 2010"}, {"source": "golbeck & mauriello 2016", "target": "acquisti & gross 2006"}, {"source": "golbeck & mauriello 2016", "target": "dwyer et al 2007"}, {"source": "golbeck & mauriello 2016", "target": "debatin et al 2009"}, {"source": "golbeck & mauriello 2016", "target": "litt 2013"}, {"source": "golbeck & mauriello 2016", "target": "lin & liu 2012"}, {"source": "govani & pashley 2005", "target": "cranor et al 1999"}, {"source": "hajli & lin 2016", "target": "govani & pashley 2005"}, {"source": "hajli & lin 2016", "target": "acquisti & gross 2006"}, {"source": "hazari & brown 2013", "target": "debatin et al 2009"}, {"source": "hazari & brown 2013", "target": "dwyer et al 2007"}, {"source": "hazari & brown 2013", "target": "graeff & harmon 2002"}, {"source": "hazari & brown 2013", "target": "hoofnagle et al 2010"}, {"source": "hazari & brown 2013", "target": "youn 2009"}, {"source": "heirman et al 2013", "target": "youn 2009"}, {"source": "hossain & zhang 2015", "target": "johnson et al 2012"}, {"source": "hossain & zhang 2015", "target": "madejski et al 2012"}, {"source": "jensen et al 2005", "target": "cranor et al 1999"}, {"source": "johnson et al 2012", "target": "acquisti & gross 2006"}, {"source": "johnson et al 2012", "target": "liu et al 2011"}, {"source": "johnson et al 2012", "target": "madejski et al 2012"}, {"source": "keith et al 2013", "target": "acquisti & gross 2006"}, {"source": "keith et al 2013", "target": "paine et al 2007"}, {"source": "keith et al 2013", "target": "posey et al 2010"}, {"source": "kezer et al 2016", "target": "acquisti & gross 2006"}, {"source": "kezer et al 2016", "target": "bartsch & dienlin 2016"}, {"source": "kezer et al 2016", "target": "hoofnagle et al 2010"}, {"source": "kezer et al 2016", "target": "litt 2013"}, {"source": "kezer et al 2016", "target": "taddicken 2014"}, {"source": "kisilevich & mansmann 2010", "target": "acquisti & gross 2006"}, {"source": "kisilevich & mansmann 2010", "target": "dwyer et al 2007"}, {"source": "kisilevich & mansmann 2010", "target": "govani & pashley 2005"}, {"source": "kisilevich & mansmann 2010", "target": "young & quan-haase 2009"}, {"source": "krasnova & kift 2012", " ...

# %% [markdown]
# Count most common variables:

# %%
variables = []
with open(filepath, 'rU') as fd:
    rd = csv.reader(fd, delimiter="\t", quotechar='"')
    for row in rd:
        if row[0] != "year":
            spl = [r.lower().strip() for r in row[8].split(",")]
            spl = [s for s in spl if s != ""]
            variables.extend(spl)

# %%
from collections import Counter
v = Counter(variables)

# %%
v.most_common()
# Out:
# [('privacy concern', 20),
#  ('age', 14),
#  ('gender', 11),
#  ('trust', 10),
#  ('privacy concerns', 8),
#  ('privacy attitudes', 7),
#  ('information disclosure', 6),
#  ('self-disclosure', 5),
#  ('privacy awareness', 4),
#  ('privacy behavior', 3),
#  ('knowledge', 3),
#  ('privacy control', 3),
#  ('income', 3),
#  ('privacy settings', 3),
#  ('perceived risk', 3),
#  ('privacy knowledge', 3),
#  ('privacy protection', 2),
#  ('social influence', 2),
#  ('perceived rewards', 2),
#  ('perceived benefits', 2),
#  ('privacy social norms', 2),
#  ('perceived severity', 2),
#  ('risk', 2),
#  ('privacy protection strategies', 2),
#  ('privacy breaches', 2),
#  ('control over personal information', 2),
#  ('privacy protection behaviors', 2),
#  ('willingness to pay for privacy', 2),
#  ('concern about unwanted audiences', 2),
#  ('disclosure', 2),
#  ('internet use', 2),
#  ('use', 2),
#  ('interest', 2),
#  ('information control', 2),
#  ('perceived vulnerability', 2),
#  ('behavior', 2),
#  ('sharing intentions', 2),
#  ('education', 2),
#  ('teen privacy concern', 1),
#  ('perceived comprehension of privacy notices', 1),
#  ('trust in online network', 1),
#  ('common-dread', 1),
#  ('privacy behaviors (specific)', 1),
#  ('profile update frequency', 1),
#  ('social network', 1),
#  ('intensity of sns use', 1),
#  ('attitude toward osns', 1),
#  ('perceived reciprocity', 1),
#  ('awareness of institutional surveillance', 1),
#  ('trust in institutions', 1),
#  ('fear', 1),
#  ('parent concern for teen', 1),
#  ('intent to disclose', 1),
#  ('policy knowledge', 1),
#  ('occupation', 1),
#  ('chronic-catastrophic', 1),
#  ('data stored on sns', 1),
#  ('how long used', 1),
#  ('voluntariness', 1),
#  ('perceived usefulness', 1),
#  ('behavior intent', 1),
#  ('type of data', 1),
#  ('level of disclosure on osns', 1),
#  ('improper access', 1),
#  ('number of applications', 1),
#  ('privacy tools use', 1),
#  ('social network use', 1),
#  ('perceived control', 1),
#  ('awareness', 1),
#  ('information provided', 1),
#  ('default privacy settings attitude', 1),
#  ('perceived control of information', 1),
#  ('self-efficacy', 1),
#  ('belief in privacy rights', 1),
#  ('sites used', 1),
#  ('privacy suspicious', 1),
#  ('personal privacy experience', 1),
#  ('privacy disposition', 1),
#  ('technical familiarity', 1),
#  ('perceived privacy risks', 1),
#  ('trustworthiness', 1),
#  ('social privacy behavior', 1),
#  ('internet use diversity', 1),
#  ('sns usage', 1),
#  ('level of concern', 1),
#  ('proposed browser features', 1),
#  ('perceived anonymity of others', 1),
#  ('perceived individual control', 1),
#  ('privacy policy', 1),
#  ('distrust', 1),
#  ('use of information', 1),
#  ('social media usage', 1),
#  ('activity', 1),
#  ('invasion of privacy experience - self vs others', 1),
#  ('privacy policy attitude', 1),
#  ('privacy safety', 1),
#  ('internet access experiences', 1),
#  ('disclosure of pii', 1),
#  ('trust in legal assurance', 1),
#  ('computer experience', 1),
#  ('trust in individuals', 1),
#  ('perception of intrusion', 1),
#  ('alternatives for reading notices', 1),
#  ('privacy seeking behavior', 1),
#  ('exposed', 1),
#  ('reason for reading privacy notices', 1),
#  ('information sharing behavior', 1),
#  ('intention to transact', 1),
#  ('consumers\xe2\x80\x99 understanding of social media privacy policies', 1),
#  ('privacy active', 1),
#  ('privacy policy awareness', 1),
#  ('sharing tendency', 1),
#  ('content accuracy', 1),
#  ('sns self-disclosure depth', 1),
#  ('protection behavior', 1),
#  ('personal data disclosure', 1),
#  ('employment', 1),
#  ('willingness to disclose contact data', 1),
#  ('information sharing', 1),
#  ('fb use and gratifications', 1),
#  ('sharing behavior', 1),
#  ('individual privacy management', 1),
#  ('valuation of personal information', 1),
#  ('intent to share information', 1),
#  ('teen sns use', 1),
#  ('motivations', 1),
#  ('desired privacy settings', 1),
#  ('privacy action', 1),
#  ('privacy beliefs', 1),
#  ('perceived group control', 1),
#  ('privacy policy consumption', 1),
#  ('review of privacy settings after breach', 1),
#  ('attitudes toward secondary/tertiary use of personal data', 1),
#  ('teen profile visibility', 1),
#  ('audience correctness', 1),
#  ('policies', 1),
#  ('media privacy awareness', 1),
#  ('profile visibility', 1),
#  ('sharing comprehension', 1),
#  ('perceived media richness', 1),
#  ('information type', 1),
#  ('actions on tracking', 1),
#  ('internet activity', 1),
#  ('reasons for use', 1),
#  ('perceived privacy', 1),
#  ('risk-benefit balance', 1),
#  ('personal information on facebook', 1),
#  ('active', 1),
#  ('misrepresentation', 1),
#  ('types of friends', 1),
#  ('privacy settings use', 1),
#  ('contextual factors', 1),
#  ('newness', 1),
#  ('disposition to value privacy', 1),
#  ('social rewards', 1),
#  ('general caution', 1),
#  ('perceived integrity', 1),
#  ('internet literacy', 1),
#  ('willingness to disclose geographic data', 1),
#  ('general willingness', 1),
#  ('ownership of disclosure boundaries', 1),
#  ('perceived likelihood', 1),
#  ('location', 1),
#  ('privacy behaviors (categorical)', 1),
#  ('experiment condition', 1),
#  ('frequency of facebook use', 1),
#  ('existing privacy settings', 1),
#  ('perceived online community trust', 1),
#  ('linkability', 1),
#  ('reward', 1),
#  ('appropriateness', 1),
#  ('audience accuracy', 1),
#  ('privacy preferences', 1),
#  ('type of threat', 1),
#  ('attitudes on law effectiveness', 1),
#  ('general use', 1),
#  ('privacy practices', 1),
#  ('regulatory knowledge', 1),
#  ('privacy values', 1),
#  ('vulnerability to risks', 1),
#  ('privacy notice', 1),
#  ('attitude toward information sharing', 1),
#  ('group privacy management', 1),
#  ('privacy attitude', 1),
#  ('trust attitudes', 1),
#  ('changes to privacy settings after breach', 1),
#  ('data control', 1),
#  ('visibility of profile information', 1),
#  ('willingness to disclose profile data', 1),
#  ('recognition of data storage', 1),
#  ('third-party sites', 1),
#  ('usage continuation intention', 1),
#  ('trust propensity', 1),
#  ('victimhood', 1),
#  ('presence of text/audio/pictorial cues in privacy policy', 1),
#  ('awareness of importance', 1),
#  ('errors', 1),
#  ('perceived collectivism', 1),
#  ('privacy literacy', 1),
#  ('use of privacy settings', 1),
#  ('trust in sns provider', 1),
#  ('attitudes on tracking', 1),
#  ('trust of site', 1),
#  ('trust of other members', 1),
#  ('privacy self-efficacy', 1),
#  ('privacy risk beliefs', 1),
#  ('perceived individualism', 1),
#  ('secondary use', 1),
#  ('scope', 1),
#  ('opinion of use of online personal information', 1),
#  ('privacy conception', 1),
#  ('sensitivity', 1),
#  ('child vs self', 1),
#  ('reason for sharing', 1),
#  ('perceived effectiveness of privacy policy', 1),
#  ('privacy indicators', 1),
#  ('perceived privacy regulatory perception', 1),
#  ('trust behavior', 1),
#  ('development of relationships', 1),
#  ('information control skills', 1),
#  ('information sensitivity', 1),
#  ('privacy risk', 1),
#  ('penalty for information misuse', 1),
#  ('perceived publicness', 1),
#  ('persuasion knowledge', 1),
#  ('intensity of internet use', 1),
#  ('concern for unwanted audiences', 1),
#  ('personal network size', 1),
#  ('social media use', 1),
#  ('social awareness', 1),
#  ('privacy concern on facebook', 1),
#  ('privacy violations', 1),
#  ('perceived damage', 1),
#  ('trusting beliefs', 1),
#  ('privacy risk concerns', 1),
#  ('actual information disclosure', 1),
#  ('trust in privacy notices', 1),
#  ('personal info disclosed', 1),
#  ('information protection behavior', 1),
#  ('information revelation', 1),
#  ('attitudes on institutions', 1),
#  ('expertise', 1),
#  ('perceived effectiveness of industry self-regulation', 1),
#  ('privacy awareness information', 1),
#  ('perceived privacy risk', 1),
#  ('usability', 1),
#  ('control', 1),
#  ('privacy turbulence', 1),
#  ('internet use experience', 1),
#  ('fb membership', 1),
#  ('privacy intentions', 1),
#  ('numeric vs textual privacy information', 1),
#  ('online subscription and purchasing', 1),
#  ('how most accessed', 1),
#  ('experts', 1),
#  ('perceived intrusiveness', 1),
#  ('privacy understanding', 1),
#  ('sns self-disclosure amount', 1),
#  ('perceived boundary connections for disclosure on osns', 1),
#  ('awareness of privacy practices', 1),
#  ('technology', 1),
#  ('hours of use', 1),
#  ('app use', 1),
#  ('self-protection', 1),
#  ('willingness to disclose identity data', 1),
#  ('severity', 1),
#  ('social relevance', 1),
#  ('technical caution', 1),
#  ('understanding data flow', 1),
#  ('comfort', 1),
#  ('internet purchase behavior', 1),
#  ('preferred website', 1),
#  ('perceived informedness', 1),
#  ('sensitivity of profile data', 1),
#  ('visited sites', 1),
#  ('role', 1),
#  ('reject', 1),
#  ('common bond', 1),
#  ('perceptions of online risks', 1),
#  ('perceived benevolence', 1),
#  ('composition', 1),
#  ('legal assurances', 1),
#  ('privacy regulation experience', 1),
#  ('confidentiality of disclosure boundaries', 1),
#  ('privacy violation experience', 1),
#  ('realized threat', 1),
#  ('observed risks', 1),
#  ('online turbulence', 1),
#  ('enjoyment', 1),
#  ('perceived threat', 1),
#  ('login frequency', 1),
#  ('info disclosure benefits', 1),
#  ('collection', 1),
#  ('internet skills', 1),
#  ('immediacy', 1),
#  ('sharing info with third parties', 1),
#  ('regulatory preferences', 1),
#  ('source of threat', 1),
#  ('privacy behaviors', 1),
#  ('social privacy literacy', 1),
#  ('personal information', 1),
#  ('adverse experiences', 1),
#  ('online trust', 1),
#  ('privacy management', 1),
#  ('psychological need for privacy', 1),
#  ('privacy value', 1),
#  ('scenario', 1),
#  ('content correctness', 1),
#  ('common identity', 1),
#  ('trust in site', 1),
#  ('perceived anonymity of self', 1),
#  ('completeness and accuracy of information provided', 1),
#  ('opinion of online advertising', 1),
#  ('risk to self vs others', 1),
#  ('privacy signifiers', 1),
#  ('perceived ability', 1),
#  ('read privacy policy', 1),
#  ('perceived anonymity', 1),
#  ('expected benefits of sns participation', 1),
#  ('reason for joining', 1),
#  ('sns use', 1),
#  ('teen privacy strategy use', 1)]

# %%
variables = [v.split(" ") for v in variables]

# %%
import nltk
from nltk.corpus import stopwords
s_words = set(stopwords.words('english'))

# %%
variables = [[v.decode('utf-8', 'ignore') for v in var if v not in s_words] for var in variables]

# %%
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer("english")

# %%
variables = [" ".join([stemmer.stem(v) for v in var]) for var in variables]

# %%
for x in Counter(variables).most_common(): print x[0] + "\t" + str(x[1])
# Out:
# privaci concern	28
# age	14
# gender	11
# trust	10
# privaci attitud	8
# inform disclosur	6
# self-disclosur	5
# privaci awar	4
# privaci behavior	4
# privaci knowledg	3
# knowledg	3
# privaci set	3
# concern unwant audienc	3
# perceiv risk	3
# privaci control	3
# incom	3
# willing pay privaci	2
# activ	2
# risk	2
# privaci valu	2
# social influenc	2
# internet use	2
# inform control	2
# privaci breach	2
# perceiv privaci risk	2
# disclosur	2
# privaci protect	2
# control person inform	2
# perceiv sever	2
# use	2
# privaci protect behavior	2
# perceiv vulner	2
# interest	2
# privaci protect strategi	2
# educ	2
# privaci social norm	2
# perceiv benefit	2
# behavior	2
# share intent	2
# perceiv reward	2
# trust site	2
# presenc text/audio/pictori cue privaci polici	1
# composit	1
# common-dread	1
# reason use	1
# comput experi	1
# trust legal assur	1
# site use	1
# confidenti disclosur boundari	1
# profil updat frequenc	1
# perceiv boundari connect disclosur osn	1
# content correct	1
# privaci self-efficaci	1
# altern read notic	1
# info disclosur benefit	1
# fear	1
# privaci concept	1
# privaci safeti	1
# perceiv privaci regulatori percept	1
# audienc accuraci	1
# sns self-disclosur amount	1
# locat	1
# regulatori prefer	1
# expos	1
# reason join	1
# sensit	1
# audienc correct	1
# trust attitud	1
# behavior intent	1
# internet use divers	1
# visibl profil inform	1
# privaci seek behavior	1
# number applic	1
# perceiv informed	1
# attitud toward inform share	1
# social network use	1
# voluntari	1
# self-efficaci	1
# share tendenc	1
# content accuraci	1
# propos browser featur	1
# third-parti site	1
# review privaci set breach	1
# type friend	1
# privaci polici awar	1
# disposit valu privaci	1
# social privaci behavior	1
# social network	1
# group privaci manag	1
# trust behavior	1
# perceiv media rich	1
# awar privaci practic	1
# level concern	1
# willing disclos ident data	1
# willing disclos profil data	1
# internet use experi	1
# person privaci experi	1
# secondari use	1
# level disclosur osn	1
# chronic-catastroph	1
# social media use	1
# person inform	1
# inform share	1
# privaci behavior (categorical)	1
# distrust	1
# privaci violat	1
# risk self vs other	1
# develop relationship	1
# general use	1
# penalti inform misus	1
# share info third parti	1
# teen privaci strategi use	1
# enjoy	1
# attitud track	1
# perceiv group control	1
# privaci behavior (specific)	1
# intent share inform	1
# common ident	1
# social reward	1
# privaci prefer	1
# intens internet use	1
# long use	1
# persuas knowledg	1
# parent concern teen	1
# privaci practic	1
# privaci manag	1
# expertis	1
# awar	1
# use privaci set	1
# privaci awar inform	1
# visit site	1
# expert	1
# collect	1
# onlin trust	1
# teen sns use	1
# opinion onlin advertis	1
# access	1
# privaci activ	1
# perceiv public	1
# improp access	1
# new	1
# social relev	1
# sns self-disclosur depth	1
# data store sns	1
# linkabl	1
# perceiv likelihood	1
# privaci notic	1
# understand data flow	1
# person network size	1
# individu privaci manag	1
# sourc threat	1
# privaci signifi	1
# invas privaci experi - self vs other	1
# attitud law effect	1
# disclosur pii	1
# inform type	1
# inform sensit	1
# reward	1
# trustworthi	1
# consum understand social media privaci polici	1
# opinion use onlin person inform	1
# type threat	1
# general caution	1
# polici knowledg	1
# privaci turbul	1
# complet accuraci inform provid	1
# technolog	1
# regulatori knowledg	1
# trust institut	1
# polici	1
# perceiv anonym	1
# privaci polici	1
# internet literaci	1
# perceiv effect industri self-regul	1
# hour use	1
# privaci concern facebook	1
# reason read privaci notic	1
# perceiv threat	1
# attitud toward osn	1
# privaci action	1
# inform provid	1
# privaci indic	1
# percept intrus	1
# attitud institut	1
# perceiv control	1
# type data	1
# trust onlin network	1
# frequenc facebook use	1
# trust privaci notic	1
# data control	1
# perceiv benevol	1
# privaci polici attitud	1
# fb use gratif	1
# onlin subscript purchas	1
# use inform	1
# victimhood	1
# perceiv damag	1
# misrepresent	1
# legal assur	1
# chang privaci set breach	1
# teen privaci concern	1
# percept onlin risk	1
# trust member	1
# experi condit	1
# ownership disclosur boundari	1
# scope	1
# child vs self	1
# perceiv privaci	1
# risk-benefit balanc	1
# inform control skill	1
# usag continu intent	1
# person info disclos	1
# privaci regul experi	1
# protect behavior	1
# self-protect	1
# expect benefit sns particip	1
# vulner risk	1
# advers experi	1
# social media usag	1
# action track	1
# contextu factor	1
# privaci suspici	1
# internet activ	1
# perceiv onlin communiti trust	1
# perceiv intrus	1
# desir privaci set	1
# privaci set use	1
# perceiv comprehens privaci notic	1
# perceiv control inform	1
# inform protect behavior	1
# privaci polici consumpt	1
# reason share	1
# awar institut surveil	1
# internet purchas behavior	1
# awar import	1
# employ	1
# trust belief	1
# perceiv individu	1
# technic caution	1
# error	1
# psycholog need privaci	1
# internet skill	1
# perceiv anonym other	1
# control	1
# privaci risk concern	1
# perceiv reciproc	1
# fb membership	1
# perceiv collectiv	1
# observ risk	1
# media privaci awar	1
# privaci risk belief	1
# privaci risk	1
# numer vs textual privaci inform	1
# privaci tool use	1
# motiv	1
# login frequenc	1
# privaci understand	1
# sever	1
# occup	1
# profil visibl	1
# internet access experi	1
# trust propens	1
# privaci violat experi	1
# default privaci set attitud	1
# prefer websit	1
# person inform facebook	1
# perceiv anonym self	1
# perceiv use	1
# comfort	1
# trust sns provid	1
# belief privaci right	1
# intent disclos	1
# role	1
# perceiv abil	1
# reject	1
# common bond	1
# app use	1
# trust individu	1
# sensit profil data	1
# valuat person inform	1
# share comprehens	1
# willing disclos contact data	1
# immediaci	1
# onlin turbul	1
# inform share behavior	1
# general willing	1
# privaci intent	1
# social awar	1
# usabl	1
# inform revel	1
# actual inform disclosur	1
# sns usag	1
# share behavior	1
# attitud toward secondary/tertiari use person data	1
# teen profil visibl	1
# person data disclosur	1
# privaci disposit	1
# appropri	1
# perceiv individu control	1
# scenario	1
# privaci literaci	1
# read privaci polici	1
# exist privaci set	1
# technic familiar	1
# perceiv effect privaci polici	1
# perceiv integr	1
# recognit data storag	1
# intens sns use	1
# realiz threat	1
# intent transact	1
# social privaci literaci	1
# sns use	1
# privaci belief	1
# willing disclos geograph data	1

# %%
unique_words = {}
for x in variables:
    spl = x.split(" ")
    for word in spl:
        if word in unique_words:
            unique_words[word].append(x)
        else:
            unique_words[word] = [x]

# %%
for word in sorted(unique_words):
    print len(Counter(unique_words[word]))
# Out:
# 1
# 1
# 1
# 1
# 3
# 3
# 2
# 3
# 1
# 1
# 1
# 1
# 1
# 1
# 3
# 1
# 1
# 1
# 2
# 10
# 3
# 9
# 1
# 14
# 4
# 3
# 1
# 1
# 3
# 3
# 1
# 2
# 1
# 1
# 1
# 1
# 1
# 1
# 2
# 1
# 1
# 1
# 1
# 2
# 1
# 1
# 7
# 1
# 1
# 1
# 1
# 1
# 1
# 2
# 1
# 1
# 10
# 2
# 1
# 1
# 12
# 1
# 1
# 1
# 1
# 6
# 10
# 2
# 1
# 1
# 1
# 3
# 1
# 1
# 1
# 1
# 1
# 9
# 1
# 1
# 1
# 3
# 1
# 1
# 2
# 1
# 1
# 1
# 3
# 1
# 1
# 3
# 1
# 1
# 2
# 1
# 2
# 1
# 1
# 1
# 1
# 1
# 4
# 1
# 1
# 3
# 25
# 1
# 3
# 1
# 2
# 7
# 1
# 9
# 2
# 1
# 1
# 5
# 1
# 2
# 2
# 1
# 1
# 3
# 1
# 1
# 1
# 3
# 5
# 1
# 1
# 1
# 1
# 1
# 1
# 4
# 1
# 1
# 5
# 1
# 1
# 1
# 1
# 8
# 2
# 3
# 3
# 1
# 1
# 1
# 1
# 1
# 1
# 34
# 3
# 10
# 1
# 1
# 10
# 2
# 3
# 1
# 79
# 6
# 1
# 1
# 5
# 3
# 1
# 1
# 2
# 3
# 1
# 4
# 1
# 1
# 1
# 3
# 1
# 1
# 1
# 1
# 1
# 3
# 1
# 1
# 10
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 4
# 3
# 2
# 1
# 1
# 3
# 8
# 2
# 10
# 1
# 4
# 1
# 2
# 9
# 12
# 1
# 1
# 1
# 2
# 1
# 1
# 1
# 2
# 1
# 5
# 1
# 1
# 1
# 1
# 1
# 4
# 1
# 3
# 2
# 1
# 15
# 1
# 2
# 4
# 3
# 1
# 1
# 1
# 3
# 27
# 2
# 1
# 1
# 2
# 3
# 1
# 1
# 4
# 2
# 1
# 6
